# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([1,5,10, 20, 40, 80]);

# %%
x=[1,5,10, 15, 20]
y=[10,20,30,40,50]
plt.plot(x,y)

# %%
fix , ax = plt.subplots()
ax.plot(x,y);

# %%
fig, ax = plt.subplots()
ax.plot(x,y);
ax.set(title='Exercise 8', xlabel="Xaxis Goofball", ylabel='Yaxis Goofball')
fig.savefig('images/Exercise8SaveFig.png')
