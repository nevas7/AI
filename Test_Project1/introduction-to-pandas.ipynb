# %%
import pandas as pd

# %% [markdown]
# ### 2 main datatypes - Series(1-Dimensional) & DataFrame(2-Dimensional)

# %%
cars = pd.Series(["Ford", "Chevrolet", "Audi"])

# %%
cars
# Out:
# 0         Ford
# 1    Chevrolet
# 2         Audi
# dtype: str

# %%
colours = pd.Series(["Black", "White", "Green"])

# %%
colours
# Out:
# 0    Black
# 1    White
# 2    Green
# dtype: str

# %%
car_data = pd.DataFrame({"Car make": cars, "Color":colours})

# %%
car_data
# Out:
#     Car make  Color
# 0       Ford  Black
# 1  Chevrolet  White
# 2       Audi  Green

# %%
car_sales = pd.read_csv("car-sales.csv");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported-car-sales.csv", index=0)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Describe Data

# %%
car_sales.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 5000, 27000])

# %%
car_prices.mean(numeric_only=True)
# Out:
# np.float64(11666.666666666666)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ### Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animals = pd.Series(["Cat", "Dog", "Birds", "Dinos", "Pandas"], index=[0,3,4,5,3])

# %%
animals
# Out:
# 0       Cat
# 3       Dog
# 4     Birds
# 5     Dinos
# 3    Pandas
# dtype: str

# %%
animals.loc[3]
# Out:
# 3       Dog
# 3    Pandas
# dtype: str

# %%
animals.iloc[:3]
# Out:
# 0      Cat
# 3      Dog
# 4    Birds
# dtype: str

# %%
F1Teams = pd.Series(['Audi', 'Cadillac', 'Red Bull', 'Alpha Tauri', "Mercedes Petronas"], index=[0,1,2,3,4])

# %%
F1Teams
# Out:
# 0                 Audi
# 1             Cadillac
# 2             Red Bull
# 3          Alpha Tauri
# 4    Mercedes Petronas
# dtype: str

# %%
F1Teams.loc[:3]
# Out:
# 0           Audi
# 1       Cadillac
# 2       Red Bull
# 3    Alpha Tauri
# dtype: str

# %%
animals.iloc[:3]
# Out:
# 0      Cat
# 3      Dog
# 4    Birds
# dtype: str

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales[car_sales["Make"]== 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
whiteToyotas = car_sales[(car_sales["Make"] == 'Toyota') & (car_sales["Colour"] == "White")]
whiteToyotas
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
whiteToyotas.mean(numeric_only=True)
# Out:
# Odometer (KM)    105021.5
# Doors                 4.0
# dtype: float64

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales.hist()
# Out:
# array([[<Axes: title={'center': 'Odometer (KM)'}>,
#         <Axes: title={'center': 'Doors'}>]], dtype=object)

# %%
car_sales['Price'] = car_sales["Price"].replace('[\\$,]','', regex=True).astype(float)

# %%
car_sales['Price']
# Out:
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: str

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Seats'] = pd.Series([4,4,4,4,4])
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    4.0
# 1   Honda    Red          87899      4   5000.0    4.0
# 2  Toyota   Blue          32549      3   7000.0    4.0
# 3     BMW  Black          11179      5  22000.0    4.0
# 4  Nissan  White         213095      4   3500.0    4.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_sales['Seats'] = car_sales['Seats'].fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    4.0
# 1   Honda    Red          87899      4   5000.0    4.0
# 2  Toyota   Blue          32549      3   7000.0    4.0
# 3     BMW  Black          11179      5  22000.0    4.0
# 4  Nissan  White         213095      4   3500.0    4.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
car_sales['Fuel per 100 KM'] = [3.0, 4.5, 6.0, 7.0, 8.5, 6.5, 8.0, 2.5, 4.6, 2.3]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 9  Nissan  White          31600      4   9700.0    5.0              2.3

# %%
car_sales['Total Fuel Used'] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel per 100 KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 9  Nissan  White          31600      4   9700.0    5.0              2.3
#
#    Total Fuel Used
# 0         4501.290
# 1         3955.455
# 2         1952.940
# 3          782.530
# 4        18113.075
# 5         6448.845
# 6         3655.840
# ...

# %%
car_sales['Total Fuel Used (L)'] = car_sales['Total Fuel Used']

# %%
car_sales['Number Of Wheels'] = 4

# %%
car_sales['Passed Road Safety'] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 9  Nissan  White          31600      4   9700.0    5.0              2.3
#
#    Total Fuel Used  Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 0         4501.290             4501.290                 4                True
# ...

# %%
car_sales = car_sales.drop('Total Fuel Used', axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 9  Nissan  White          31600      4   9700.0    5.0              2.3
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 0             4501.290                 4                True
# ...

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 1             3955.455                 4                True
# 8             2760.000                 4                True
# 4            18113.075                 4                True
# 3              782.530                 4                True
# 5             6448.845                 4                True

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 9  Nissan  White          31600      4   9700.0    5.0              2.3
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 8             2760.000                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 9  Nissan  White          31600      4   9700.0    5.0              2.3
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 0             4501.290                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=0.2)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100 KM  \
# 2  Toyota   Blue          32549      3  7000.0    4.0              6.0
# 7   Honda   Blue          54738      4  7000.0    5.0              2.5
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 2              1952.94                 4                True
# 7              1368.45                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100 KM  \
# 0  Toyota   Blue          32549      3  7000.0    4.0              6.0
# 1   Honda   Blue          54738      4  7000.0    5.0              2.5
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety
# 0              1952.94                 4                True
# 1              1368.45                 4                True

# %%
car_sales["Odometer (Miles)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  Toyota  White         150043      4   4000.0    4.0              3.0
# 1   Honda    Red          87899      4   5000.0    4.0              4.5
# 2  Toyota   Blue          32549      3   7000.0    4.0              6.0
# 3     BMW  Black          11179      5  22000.0    4.0              7.0
# 4  Nissan  White         213095      4   3500.0    4.0              8.5
# 5  Toyota  Green          99213      4   4500.0    5.0              6.5
# 6   Honda   Blue          45698      4   7500.0    5.0              8.0
# 7   Honda   Blue          54738      4   7000.0    5.0              2.5
# 8  Toyota  White          60000      4   6250.0    5.0              4.6
# 9  Nissan  White          31600      4   9700.0    5.0              2.3
#
#    Total Fuel Used (L)  Number Of Wheels  Passed Road Safety  Odometer (Miles)
# 0             4501.290                 4                True         93776.875
# ...
