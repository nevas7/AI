# %% [markdown]
# # Test Jupyter Native Launch

# %% [markdown]
# ### M - for markdown
# ### Y - for Code mode
# ### Esc - for command mode
# ### Enter - to go into edit mode
# ### To Install Pandas without conda  for a specific notebook - %pip install pandas
# ### To Install Matplot lib without conda  for a specific notebook - %pip install matplotlib
# ### To display a mardown image - ``` ![image](../Jupyter%20Exercise/6_steps_machine_learning_tools.png) ```

# %% [markdown]
# ## Global Retention Program
# ##### This project is about classifying whethere a renewal opportunity will be a success or not

# %% [markdown]
# #### Need to install this only once - %pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("heart-disease.csv")

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Need to install this only once - %pip install matplotlib

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ![image](../Jupyter%20Exercise/images/6_steps_machine_learning_tools.png)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 684E-1E12
#
#  Directory of C:\Users\nsridhar\Jupyter Exercise
#
# 03/19/2026  08:16 AM    <DIR>          .
# 03/19/2026  07:43 AM    <DIR>          ..
# 03/19/2026  08:08 AM    <DIR>          .ipynb_checkpoints
# 03/19/2026  07:53 AM           534,598 6_steps_machine_learning_tools.png
# 03/19/2026  08:16 AM            22,619 example-notebook.ipynb
# 03/19/2026  07:28 AM            11,328 heart-disease.csv
#                3 File(s)        568,545 bytes
#                3 Dir(s)  49,941,958,656 bytes free
