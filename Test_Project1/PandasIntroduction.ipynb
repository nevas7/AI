# %%
import pandas as pd

# %% [markdown]
# 2 main data types - Series(1-Dimesion Column) & Dataframe(2-Dimension Column)

# %%
make = pd.Series(['Ford', 'TATA', 'Porsche', 'Toyota'])
make
# Out:
# 0       Ford
# 1       TATA
# 2    Porsche
# 3     Toyota
# dtype: object

# %%
color = pd.Series(['Black', 'Red', 'Matte Black', 'White'])

# %%
color
# Out:
# 0          Black
# 1            Red
# 2    Matte Black
# 3          White
# dtype: object

# %%
dfExample = pd.DataFrame({'Make': make, 'Color': color})

# %%
dfExample
# Out:
#       Make        Color
# 0     Ford        Black
# 1     TATA          Red
# 2  Porsche  Matte Black
# 3   Toyota        White
